# %%
import numpy as np
'''
Author: LawsonAbs
Date: 2021-09-16 18:53:02
LastEditTime: 2021-09-16 19:02:08
FilePath: /daguan/code/utils/tests.py
仔细分析每个文件在每个类别下的输出值
'''

import os
import matplotlib.pyplot as plt
from collections import Counter
def statistic(submission_path):
    id_label = {}
    with open(submission_path,'r') as f:
        f.readline()
        for line in f:
            iid,label = line.strip("\n").split(",")
            id_label[iid] = label
    cnt = Counter()
    for label in id_label.values():
        
        cnt[label]+=1
    
    print(cnt)
    return cnt



if __name__ == "__main__":
    x = [0,1]
    # cnt = dict(statistic("/home/lawson/program/daguan/submission_ngram_5.csv"))
    cnt = dict(statistic("/home/lawson/program/daguan/prediction_result/submission_60000_10.csv"))
    # print(type(cnt))
    x = list(cnt.keys())
    index = np.arange(len(x))
    
    y = list(cnt.values())
    # y2 = list(cnt2.values())
    print(y)
    # print(y2)
    plt.figure(figsize=(30,10))
    for a,b in zip(x,y):    
        plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=17)        
    
    # for a,b in zip(x,y2):
    #     plt.text(x, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=17)        
    plt.tick_params(labelsize=15)
    plt.xlabel("class",fontdict={"fontsize":17})
    plt.ylabel("num",fontdict={"fontsize":17})
    plt.bar(x,y,width=0.3,align='center') # 画柱状图
    # plt.bar(index+0.4,y2,width=0.3,align='center') # 画柱状图
    plt.show()
# Out:
# Counter({'1-9': 859, '1-1': 621, '5-30': 555, '2-3': 432, '1-4': 388, '2-6': 376, '2-2': 333, '2-33': 275, '1-10': 274, '6-15': 267, '4-7': 241, '6-29': 150, '5-35': 131, '6-28': 111, '6-8': 110, '2-25': 99, '5-12': 92, '2-11': 89, '6-13': 78, '5-22': 78, '6-19': 75, '6-31': 71, '6-34': 61, '6-21': 61, '2-14': 57, '6-32': 46, '2-17': 27, '5-24': 22, '7-16': 6, '6-20': 6, '10-26': 4, '9-23': 3, '8-27': 2, '3-5': 2, '8-18': 2})
# [376, 388, 859, 621, 555, 275, 432, 267, 61, 274, 333, 110, 75, 61, 111, 150, 71, 131, 89, 27, 241, 92, 78, 99, 57, 22, 78, 6, 46, 6, 3, 2, 4, 2, 2]

# %%
# 分析train+test中每行文本的长度
import matplotlib.pyplot as plt
def show_text_length(data_path):
    text_length = []
    with open(data_path,'r') as f:
        for line in f:
            line = line.strip("\n").split() # 以空格分
            text_length.append(len(line))
    plt.hist(text_length,bins=40,facecolor="blue",edgecolor="white",alpha=0.9)
data_path = "/home/lawson/program/daguan/code/data/all.txt"
show_text_length(data_path)
