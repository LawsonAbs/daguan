# %%
import numpy as np
'''
Author: LawsonAbs
Date: 2021-09-16 18:53:02
LastEditTime: 2021-09-16 19:02:08
FilePath: /daguan/risk_data_grand/utils/tests.py
仔细分析每个文件在每个类别下的输出值
'''

import os
import matplotlib.pyplot as plt
from collections import Counter
def statistic(submission_path):
    id_label = {}
    with open(submission_path,'r') as f:
        f.readline()
        for line in f:
            iid,label = line.strip("\n").split(",")
            id_label[iid] = label
    cnt = Counter()
    for label in id_label.values():
        
        cnt[label]+=1
    
    print(cnt)
    return cnt



if __name__ == "__main__":
    x = [0,1]
    cnt = dict(statistic("/home/lawson/program/daguan/submission_ngram_5.csv"))
    # cnt = dict(statistic("/home/lawson/program/daguan/submission_ensemble.csv"))
    # print(type(cnt))
    x = list(cnt.keys())
    index = np.arange(len(x))
    
    y = list(cnt.values())
    # y2 = list(cnt2.values())
    print(y)
    # print(y2)
    plt.figure(figsize=(30,10))
    for a,b in zip(x,y):    
        plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=17)        
    
    # for a,b in zip(x,y2):
    #     plt.text(x, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=17)        
    plt.tick_params(labelsize=15)
    plt.xlabel("class",fontdict={"fontsize":17})
    plt.ylabel("num",fontdict={"fontsize":17})
    plt.bar(x,y,width=0.3,align='center') # 画柱状图
    # plt.bar(index+0.4,y2,width=0.3,align='center') # 画柱状图
    plt.show()
# Out:
# Counter({'1-9': 830, '5-30': 631, '2-3': 449, '1-4': 425, '1-1': 404, '2-6': 373, '2-33': 361, '2-2': 340, '6-15': 303, '4-7': 285, '1-10': 255, '6-29': 157, '5-35': 142, '5-12': 112, '6-28': 110, '6-8': 103, '6-13': 95, '2-25': 93, '6-19': 82, '2-14': 72, '2-11': 65, '6-31': 64, '6-34': 62, '6-21': 58, '6-32': 52, '5-22': 50, '5-24': 20, '2-17': 6, '6-20': 5})
# [373, 425, 285, 631, 361, 449, 303, 62, 255, 340, 103, 82, 830, 110, 404, 58, 157, 64, 142, 65, 6, 112, 95, 93, 72, 20, 50, 52, 5]

# %%
# 分析train+test中每行文本的长度
import matplotlib.pyplot as plt
def show_text_length(data_path):
    text_length = []
    with open(data_path,'r') as f:
        for line in f:
            line = line.strip("\n").split() # 以空格分
            text_length.append(len(line))
    plt.hist(text_length,bins=40,facecolor="blue",edgecolor="white",alpha=0.9)
data_path = "/home/lawson/program/daguan/risk_data_grand/data/all.txt"
show_text_length(data_path)
