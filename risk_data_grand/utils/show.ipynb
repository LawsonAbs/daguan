# %%
import numpy as np
'''
Author: LawsonAbs
Date: 2021-09-16 18:53:02
LastEditTime: 2021-09-16 19:02:08
FilePath: /daguan/risk_data_grand/utils/tests.py
仔细分析每个文件在每个类别下的输出值
'''

import os
import matplotlib.pyplot as plt
from collections import Counter
def statistic(submission_path):
    id_label = {}
    with open(submission_path,'r') as f:
        f.readline()
        for line in f:
            iid,label = line.strip("\n").split(",")
            id_label[iid] = label
    cnt = Counter()
    for label in id_label.values():
        
        cnt[label]+=1
    
    print(cnt)
    return cnt



if __name__ == "__main__":
    x = [0,1]
    cnt = dict(statistic("/home/lawson/program/daguan/submission_epoch_10_ls_0.1.csv"))
    cnt2 = dict(statistic("/home/lawson/program/daguan/submission_ensemble.csv"))
    # print(type(cnt))
    x = list(cnt.keys())
    index = np.arange(len(x))
    
    y = list(cnt.values())
    y2 = list(cnt2.values())
    print(y)
    print(y2)
    plt.figure(figsize=(30,10))
    for a,b in zip(x,y):    
        plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=17)        
    
    # for a,b in zip(x,y2):
    #     plt.text(x, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=17)        
    plt.tick_params(labelsize=15)
    plt.xlabel("class",fontdict={"fontsize":17})
    plt.ylabel("num",fontdict={"fontsize":17})
    plt.bar(x,y,width=0.3,align='center') # 画柱状图
    # plt.bar(index+0.4,y2,width=0.3,align='center') # 画柱状图
    plt.show()
# Out:
# Counter({'1-9': 1002, '5-30': 555, '1-1': 514, '2-3': 441, '1-4': 393, '2-6': 380, '2-2': 314, '6-15': 300, '2-33': 266, '1-10': 263, '4-7': 212, '6-29': 142, '5-35': 131, '6-8': 119, '2-11': 113, '6-28': 101, '2-25': 99, '5-12': 86, '5-22': 72, '6-13': 71, '6-19': 70, '6-31': 66, '2-14': 66, '6-34': 62, '6-21': 62, '6-32': 43, '2-17': 20, '5-24': 20, '6-20': 6, '7-16': 5, '9-23': 4, '10-26': 2, '3-5': 2, '8-27': 1, '8-18': 1})
# Counter({'1-9': 783, '5-30': 576, '1-1': 463, '2-3': 451, '1-4': 416, '2-6': 370, '2-2': 331, '6-15': 307, '2-33': 286, '1-10': 280, '4-7': 262, '6-29': 156, '5-35': 155, '6-28': 122, '6-8': 116, '5-12': 110, '2-11': 98, '2-25': 97, '6-31': 80, '6-13': 79, '6-19': 77, '2-14': 73, '5-22': 70, '6-34': 66, '6-21': 59, '6-32': 49, '2-17': 28, '5-24': 27, '6-20': 12, '7-16': 4, '8-18': 1})
# [380, 393, 1002, 514, 555, 266, 441, 300, 62, 263, 314, 119, 70, 62, 101, 142, 66, 72, 131, 113, 212, 86, 20, 71, 99, 20, 4, 66, 43, 6, 5, 1, 2, 1, 2]
# [370, 416, 783, 576, 286, 451, 307, 66, 280, 331, 116, 77, 59, 122, 463, 262, 156, 80, 155, 98, 110, 28, 97, 27, 73, 79, 70, 4, 49, 12, 1]

# %%
# 分析train+test中每行文本的长度
import matplotlib.pyplot as plt
def show_text_length(data_path):
    text_length = []
    with open(data_path,'r') as f:
        for line in f:
            line = line.strip("\n").split() # 以空格分
            text_length.append(len(line))
    plt.hist(text_length,bins=40,facecolor="blue",edgecolor="white",alpha=0.9)
data_path = "/home/lawson/program/daguan/risk_data_grand/data/all.txt"
show_text_length(data_path)
